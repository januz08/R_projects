# %% [markdown]
# <a href="https://colab.research.google.com/github/januz08/R_projects/blob/main/Proyecto_Nuevo_Ingreso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
#     * Relación entre género y selección  vocacional
#     * Influencia de la edad en la elección de carrera universitaria

# %%
data_frame = pd.DataFrame(pd.read_excel('info_Ingresos_Estudiantes.xlsx'))

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4452 entries, 0 to 4451
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Carnet              4452 non-null   object
#  1   Nombre              4452 non-null   object
#  2   Estatus             4452 non-null   object
#  3   Sexo                4452 non-null   object
#  4   Materias_Inscritas  4452 non-null   int64
#  5   Edad                4452 non-null   int64
#  6   Carrera             4452 non-null   object
#  7   Facultad            4452 non-null   object
#  8   Plan de estudios    4452 non-null   object
#  9   Anio                4452 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 347.9+ KB

# %%
#data_frame.describe()

# %%
data_frame = data_frame
data_frame
# Out:
#             Estatus Sexo  Materias_Inscritas  Edad                   Carrera  \
# 0     Nuevo Ingreso    M                   1    25     INGENIERIA AGRONOMICA
# 1     Nuevo Ingreso    M                   1    26     INGENIERIA AGRONOMICA
# 2     Nuevo Ingreso    M                   4    23     INGENIERIA AGRONOMICA
# 3     Nuevo Ingreso    M                   1    28     INGENIERIA AGRONOMICA
# 4     Nuevo Ingreso    F                   4    28     INGENIERIA AGRONOMICA
# ...             ...  ...                 ...   ...                       ...
# 4447  Nuevo Ingreso    F                   5    18  TECNICO EN IDIOMA INGLES
# 4448  Nuevo Ingreso    F                   5    18  TECNICO EN IDIOMA INGLES
# 4449  Nuevo Ingreso    M                   5    36  TECNICO EN IDIOMA INGLES
# 4450  Nuevo Ingreso    F                   3    23  TECNICO EN IDIOMA INGLES
# 4451  Nuevo Ingreso    M                   5    18  TECNICO EN IDIOMA INGLES
#
# ...

# %%
#data_frame = data_frame.drop(["Plan de estudios"], axis = 1)
data_frame = data_frame.drop(["Carnet"], axis = 1)
data_frame
# Out:
#                                 Nombre        Estatus Sexo  \
# 0      CASTRO COREAS DOUGLAS ALEXANDER  Nuevo Ingreso    M
# 1          CHICAS AMAYA FRANCISCO ABEL  Nuevo Ingreso    M
# 2       MENJIVAR REYES STEVEN JONATHAN  Nuevo Ingreso    M
# 3        TORRES APARICIO JORGE ALBERTO  Nuevo Ingreso    M
# 4         ALEMAN LEIVA  NORMA MARICELA  Nuevo Ingreso    F
# ...                                ...            ...  ...
# 4447        PINEDA REYES  KAREN LISETH  Nuevo Ingreso    F
# 4448     ROBLES GUEVARA LEYDI PATRICIA  Nuevo Ingreso    F
# 4449  RODRÍGUEZ TURCIOS OSCAR HUMBERTO  Nuevo Ingreso    M
# 4450    SARAVIA ZELAYA KARINA YAMILETH  Nuevo Ingreso    F
# 4451   VILLATORO BONILLA OSCAR ANTONIO  Nuevo Ingreso    M
#
#       Materias_Inscritas  Edad                   Carrera  \
# 0                      1    25     INGENIERIA AGRONOMICA
# 1                      1    26     INGENIERIA AGRONOMICA
# 2                      4    23     INGENIERIA AGRONOMICA
# ...

# %%
data_frame = data_frame.drop(["Nombre"], axis = 1)
data_frame
# Out:
#             Estatus Sexo  Materias_Inscritas  Edad                   Carrera  \
# 0     Nuevo Ingreso    M                   1    25     INGENIERIA AGRONOMICA
# 1     Nuevo Ingreso    M                   1    26     INGENIERIA AGRONOMICA
# 2     Nuevo Ingreso    M                   4    23     INGENIERIA AGRONOMICA
# 3     Nuevo Ingreso    M                   1    28     INGENIERIA AGRONOMICA
# 4     Nuevo Ingreso    F                   4    28     INGENIERIA AGRONOMICA
# ...             ...  ...                 ...   ...                       ...
# 4447  Nuevo Ingreso    F                   5    18  TECNICO EN IDIOMA INGLES
# 4448  Nuevo Ingreso    F                   5    18  TECNICO EN IDIOMA INGLES
# 4449  Nuevo Ingreso    M                   5    36  TECNICO EN IDIOMA INGLES
# 4450  Nuevo Ingreso    F                   3    23  TECNICO EN IDIOMA INGLES
# 4451  Nuevo Ingreso    M                   5    18  TECNICO EN IDIOMA INGLES
#
# ...

# %%
data_frame.head()
# Out:
#          Estatus Sexo  Materias_Inscritas  Edad                Carrera  \
# 0  Nuevo Ingreso    M                   1    25  INGENIERIA AGRONOMICA
# 1  Nuevo Ingreso    M                   1    26  INGENIERIA AGRONOMICA
# 2  Nuevo Ingreso    M                   4    23  INGENIERIA AGRONOMICA
# 3  Nuevo Ingreso    M                   1    28  INGENIERIA AGRONOMICA
# 4  Nuevo Ingreso    F                   4    28  INGENIERIA AGRONOMICA
#
#                            Facultad Plan de estudios  Anio
# 0  FACULTAD DE CIENCIAS AGRONOMICAS          PLAN002  2019
# 1  FACULTAD DE CIENCIAS AGRONOMICAS          PLAN002  2020
# 2  FACULTAD DE CIENCIAS AGRONOMICAS          PLAN002  2019
# 3  FACULTAD DE CIENCIAS AGRONOMICAS          PLAN002  2019
# 4  FACULTAD DE CIENCIAS AGRONOMICAS          PLAN003  2019

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4452 entries, 0 to 4451
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Estatus             4452 non-null   object
#  1   Sexo                4452 non-null   object
#  2   Materias_Inscritas  4452 non-null   int64
#  3   Edad                4452 non-null   int64
#  4   Carrera             4452 non-null   object
#  5   Facultad            4452 non-null   object
#  6   Plan de estudios    4452 non-null   object
#  7   Anio                4452 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 278.4+ KB

# %%
data_frame.isnull()
# Out:
#       Estatus   Sexo  Materias_Inscritas   Edad  Carrera  Facultad  \
# 0       False  False               False  False    False     False
# 1       False  False               False  False    False     False
# 2       False  False               False  False    False     False
# 3       False  False               False  False    False     False
# 4       False  False               False  False    False     False
# ...       ...    ...                 ...    ...      ...       ...
# 4447    False  False               False  False    False     False
# 4448    False  False               False  False    False     False
# 4449    False  False               False  False    False     False
# 4450    False  False               False  False    False     False
# 4451    False  False               False  False    False     False
#
#       Plan de estudios   Anio
# 0                False  False
# 1                False  False
# 2                False  False
# 3                False  False
# ...

# %%
data_frame.dropna()
# Out:
#             Estatus Sexo  Materias_Inscritas  Edad                   Carrera  \
# 0     Nuevo Ingreso    M                   1    25     INGENIERIA AGRONOMICA
# 1     Nuevo Ingreso    M                   1    26     INGENIERIA AGRONOMICA
# 2     Nuevo Ingreso    M                   4    23     INGENIERIA AGRONOMICA
# 3     Nuevo Ingreso    M                   1    28     INGENIERIA AGRONOMICA
# 4     Nuevo Ingreso    F                   4    28     INGENIERIA AGRONOMICA
# ...             ...  ...                 ...   ...                       ...
# 4447  Nuevo Ingreso    F                   5    18  TECNICO EN IDIOMA INGLES
# 4448  Nuevo Ingreso    F                   5    18  TECNICO EN IDIOMA INGLES
# 4449  Nuevo Ingreso    M                   5    36  TECNICO EN IDIOMA INGLES
# 4450  Nuevo Ingreso    F                   3    23  TECNICO EN IDIOMA INGLES
# 4451  Nuevo Ingreso    M                   5    18  TECNICO EN IDIOMA INGLES
#
# ...

# %%
data_frame['Materias_Inscritas'].describe()
# Out:
# count    4452.000000
# mean        4.470575
# std         1.419537
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max        15.000000
# Name: Materias_Inscritas, dtype: float64

# %%
data_frame['Edad'].describe()
# Out:
# count    4452.000000
# mean       22.684861
# std         4.645822
# min        16.000000
# 25%        20.000000
# 50%        22.000000
# 75%        24.000000
# max        60.000000
# Name: Edad, dtype: float64

# %%
pd.unique(data_frame['Estatus'])
# Out:
# array(['Nuevo Ingreso', 'Equivalencias', 'Antiguo Ingreso', 'Reingreso'],
#       dtype=object)

# %%
pd.unique(data_frame['Edad'])
# Out:
# array([25, 26, 23, 28, 22, 21, 20, 24, 30, 34, 27, 29, 19, 31, 32, 18, 17,
#        41, 46, 35, 40, 33, 37, 44, 16, 38, 39, 36, 43, 47, 45, 42, 54, 48,
#        51, 60, 53, 49])

# %%
pd.unique(data_frame['Sexo'])
# Out:
# array(['M', 'F'], dtype=object)

# %%
pd.unique(data_frame['Anio'])
# Out:
# array([2019, 2020, 2018])

# %%
pd.unique(data_frame['Materias_Inscritas'])
# Out:
# array([ 1,  4,  3,  5,  2,  6, 10,  8,  7,  9, 12, 15, 14, 11])

# %%
pd.unique(data_frame['Facultad'])
# Out:
# array(['FACULTAD DE CIENCIAS AGRONOMICAS',
#        'FACULTAD DE CIENCIAS DE LA SALUD',
#        'FACULTAD DE CIENCIAS ECONOMICAS',
#        'FACULTAD DE CIENCIAS JURIDICAS',
#        'FACULTAD DE CIENCIAS Y HUMANIDADES'], dtype=object)

# %%
data_frame.mean()
# Out:
# /var/folders/nq/l0_9gxxj3hv1_wwwd11kyscc0000gn/T/ipykernel_29621/2597474180.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_frame.mean()
# Materias_Inscritas       4.470575
# Edad                    22.684861
# Anio                  2018.998652
# dtype: float64

# %%
data_frame.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Materias_Inscritas'}>,
#         <AxesSubplot:title={'center':'Edad'}>],
#        [<AxesSubplot:title={'center':'Anio'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data_frame['Edad'].mean()
# Out:
# 22.684860736747527

# %%
sns.catplot(x = "Estatus", y = "Materias_Inscritas", data =data_frame, kind = "violin",
            hue = "Facultad", height = 5, aspect = 2);

# %%
sns.catplot(x = "Estatus", y = "Materias_Inscritas", data =data_frame, kind = "violin",
            hue = "Anio", height = 5, aspect = 2);

# %%
sns.catplot(x = "Materias_Inscritas", y = "Facultad", data =data_frame,
            hue = 'Anio',kind = "bar", height = 5, aspect = 2);

# %%
sns.catplot(x = 'Sexo' , y = "Materias_Inscritas", data =data_frame,
            hue = 'Anio',kind = "violin", height = 5, aspect = 2);

# %%
data_frame.groupby('Facultad')[['Edad']].mean().round()
# Out:
#                                     Edad
# Facultad
# FACULTAD DE CIENCIAS AGRONOMICAS    22.0
# FACULTAD DE CIENCIAS DE LA SALUD    22.0
# FACULTAD DE CIENCIAS ECONOMICAS     23.0
# FACULTAD DE CIENCIAS JURIDICAS      24.0
# FACULTAD DE CIENCIAS Y HUMANIDADES  22.0

# %%
data_frame.groupby('Facultad')[['Materias_Inscritas']].mean().round()
# Out:
#                                     Materias_Inscritas
# Facultad
# FACULTAD DE CIENCIAS AGRONOMICAS                   5.0
# FACULTAD DE CIENCIAS DE LA SALUD                   4.0
# FACULTAD DE CIENCIAS ECONOMICAS                    4.0
# FACULTAD DE CIENCIAS JURIDICAS                     5.0
# FACULTAD DE CIENCIAS Y HUMANIDADES                 5.0

# %%
df_two.describe()

# %%
df_two.info()

# %%
pd.unique(data_frame['Estatus'])

# %%
pd.unique(data_frame['Edad'])

# %%
data_frame['Edad'].describe()

# %%
pd.unique(data_frame['Facultad'])

# %%
data_frame.groupby(['Sexo','Facultad'])[['Materias_Inscritas']].mean().round()
# Out:
#                                          Materias_Inscritas
# Sexo Facultad
# F    FACULTAD DE CIENCIAS AGRONOMICAS                   5.0
#      FACULTAD DE CIENCIAS DE LA SALUD                   4.0
#      FACULTAD DE CIENCIAS ECONOMICAS                    4.0
#      FACULTAD DE CIENCIAS JURIDICAS                     5.0
#      FACULTAD DE CIENCIAS Y HUMANIDADES                 5.0
# M    FACULTAD DE CIENCIAS AGRONOMICAS                   4.0
#      FACULTAD DE CIENCIAS DE LA SALUD                   4.0
#      FACULTAD DE CIENCIAS ECONOMICAS                    4.0
#      FACULTAD DE CIENCIAS JURIDICAS                     5.0
#      FACULTAD DE CIENCIAS Y HUMANIDADES                 5.0

# %%
#revisar
data_frame.groupby(['Sexo','Facultad','Anio'])[['Carrera']].count()
# Out:
#                                               Carrera
# Sexo Facultad                           Anio
# F    FACULTAD DE CIENCIAS AGRONOMICAS   2018       53
#                                         2019       47
#                                         2020       44
#      FACULTAD DE CIENCIAS DE LA SALUD   2018      149
#                                         2019      151
#                                         2020      162
#      FACULTAD DE CIENCIAS ECONOMICAS    2018      261
#                                         2019      217
#                                         2020      230
#      FACULTAD DE CIENCIAS JURIDICAS     2018       94
#                                         2019       97
#                                         2020       84
#      FACULTAD DE CIENCIAS Y HUMANIDADES 2018      387
#                                         2019      382
#                                         2020      348
# M    ESCUELA DE POSTGRADO               2020        1
# ...

# %%
#group_by_sex = data_frame.groupby('Sexo')
#group_by_sex.mean()
#group_by_sex.describe()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[0].set_title('Sexo vs Edad')
sns.boxplot(x="Sexo", y="Edad", data=data_frame, ax=axs[0])

sns.swarmplot(x="Sexo", y="Edad", data=data_frame, color='black',
              alpha = 0.5, ax=axs[1])

#axs[1].set_title('Año vs Sexo')
#sns.boxplot(x="Anio", y="Sexo", data=data_frame, ax=axs[1])
#sns.swarmplot(x="Anio", y="Sexo", data=data_frame, color='black',
#              alpha = 0.5, ax=axs[1]);

# %%
g = sns.factorplot('Anio', 'Facultad', 'Sexo',
                   data = data_frame, kind = 'bar',
                  palette = 'muted', legend = True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
data_frame.groupby('Sexo').count()["Facultad"].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sexo'>

# %%
data_frame.groupby('Facultad')["Materias_Inscritas"].plot(kind='bar')
# Out:
# Facultad
# ESCUELA DE POSTGRADO                  AxesSubplot(0.125,0.125;0.775x0.755)
# FACULTAD DE CIENCIAS AGRONOMICAS      AxesSubplot(0.125,0.125;0.775x0.755)
# FACULTAD DE CIENCIAS DE LA SALUD      AxesSubplot(0.125,0.125;0.775x0.755)
# FACULTAD DE CIENCIAS ECONOMICAS       AxesSubplot(0.125,0.125;0.775x0.755)
# FACULTAD DE CIENCIAS JURIDICAS        AxesSubplot(0.125,0.125;0.775x0.755)
# FACULTAD DE CIENCIAS Y HUMANIDADES    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Materias_Inscritas, dtype: object

# %%
sns.violinplot( x = data_frame["Sexo"], y = data_frame["Edad"] )

# %%
corrmat = data_frame.corr()
p = sns.heatmap(corrmat, annot = True)
plt.show

# %%
sns.barplot(x='Estatus', y='Edad', hue='Sexo', data=data_frame, estimator=np.median)

# %%
sns.swarmplot(x = 'Sexo', y = 'Facultad', data = data_frame)

# %%
sns.swarmplot(x = 'Sexo', y = 'Anio', data = data_frame)

# %%
sns.swarmplot(x = 'Sexo', y = 'Edad', data = data_frame)

# %%
pip install tensorflow     # Python 3.n; SOLO SOPORTE CPU
pip install tensorflow-gpu  # Python 2.7; soporte CPU
# Out:
#   Input In [1]
#     pip install tensorflow     # Python 3.n; SOLO SOPORTE CPU
#         ^
# SyntaxError: invalid syntax

# %%
import tensorflow as tf

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

# %%
pip install --upgrade pip

# %%
pip install tf-nightly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 MB 3.1 MB/s eta 0:00:0000:0100:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.4/439.4 kB 3.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 5.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.6 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.
